# %% [markdown]
# # Atividade 0
# ### Rotação horária de 90° e shear (cisalhamento) em x

# %% [markdown]
# #### Vetor Inicial

# %% [markdown]
# ### Vetor Inicial:
# O vetor escolhido foi o seguinte:
# \begin{bmatrix}
# 6 \\
# 6
# \end{bmatrix}

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,6,6,scale=1,scale_units='xy',angles='xy')
plt.xlim(0,12)
plt.ylim(0,12)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ### Vetor Após Rotação:
#
# Após ter ume vetor arbitrário escolhido foi realizada a rotação do mesmo em 90° em sentido horário, assim se obtendo o seguinte vetor:
#
# \begin{bmatrix}
# 6 \\
# -6
# \end{bmatrix}

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,6,-6,scale=1,scale_units='xy',angles='xy')
plt.xlim(-1,6)
plt.ylim(-6,6)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ### Vetor Após Cisalhamento:
#
# Com a rotação já realizada, fazemos então o cisalhamento que basicamente resultou no deslocamento para a esquerda do vetor, resultando no seguinte vetor:
#
# \begin{bmatrix}
# 0 \\
# -6
# \end{bmatrix}

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,0,-6,scale=1,scale_units='xy',angles='xy')
plt.xlim(-6,3)
plt.ylim(-6,3)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# # Obtenção das matrizes de transformação

# %% [markdown]
# #### Explicação
# Primeiro são definidos os vetores unitários que são a base do sistema com valor unitário igual a 1

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,0,1,scale=1,scale_units='xy',angles='xy')
plt.quiver(0,0,1,0,scale=1,scale_units='xy',angles='xy')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.text(-0.20,0.40,'j',fontweight='bold')
plt.text(0.40,-0.30,'i',fontweight='bold')
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ### Vetor j:
#
# \begin{bmatrix}
# 0 \\
# 1
# \end{bmatrix}
#
# ### Vetor i:
#
# \begin{bmatrix}
# 1 \\
# 0
# \end{bmatrix}
#
# ### Matriz resultante
# Após a concatenação:
# \begin{bmatrix}
# 1 & 0 \\
# 0 & 1
# \end{bmatrix}

# %% [markdown]
# ### Após a Rotação

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,1,0,scale=1,scale_units='xy',angles='xy')
plt.quiver(0,0,0,-1,scale=1,scale_units='xy',angles='xy')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.text(0.40,0.20,'j',fontweight='bold')
plt.text(-0.25,-0.5,'i',fontweight='bold')
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ### Explicação
# Após a rotação de 90° em sentido horário dos vetores que formam a base, os valores dos vetores passaram a ser os seguintes:
#
# ### Vetor j:
#
# \begin{bmatrix}
# 1 \\
# 0
# \end{bmatrix}
#
# ### Vetor i:
#
# \begin{bmatrix}
# 0 \\
# -1
# \end{bmatrix}
#
# ### Matriz resultante da Rotação
# Após a concatenação:
# \begin{bmatrix}
# 0 & 1 \\
# -1 & 0
# \end{bmatrix}

# %% [markdown]
# ### Após o Cisalhamento

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,1,1,scale=1,scale_units='xy',angles='xy')
plt.quiver(0,0,1,0,scale=1,scale_units='xy',angles='xy')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.text(0.4,0.6,'j',fontweight='bold')
plt.text(0.40,-0.30,'i',fontweight='bold')
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ### Explicação
# Após o Cisalhamento o vetor j é inclinado para a direita e o vetor i se mantem o mesmo, com os dois ficando com os seguintes valores:
#
#
# ### Vetor j:
#
# \begin{bmatrix}
# 1 \\
# 1
# \end{bmatrix}
#
# ### Vetor i:
#
# \begin{bmatrix}
# 1 \\
# 0
# \end{bmatrix}
#
# ### Matriz resultante do Cisalhamento
# Após a concatenação:
# \begin{bmatrix}
# 1 & 1 \\
# 0 & 1
# \end{bmatrix}

# %% [markdown]
# ### Após a Rotação e o Cisalhamento

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,1,0,scale=1,scale_units='xy',angles='xy')
plt.quiver(0,0,-1,-1,scale=1,scale_units='xy',angles='xy')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.text(0.40,0.20,'j',fontweight='bold')
plt.text(-0.55,-0.3,'i',fontweight='bold')
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ### Explicação
# Após a rotação e o Cisalhamento, ocorreu um deslocamento do vetor i para a esquerda e para baixo, o que fez o valor dos vetores ficaram iguais a:
#
# ### Vetor j:
#
# \begin{bmatrix}
# 1 \\
# 0
# \end{bmatrix}
#
# ### Vetor i:
#
# \begin{bmatrix}
# -1 \\
# -1
# \end{bmatrix}

# %% [markdown]
# #### Obtenção da Matriz Transformação
# A seguir é feito a concatenação dos dois vetores e então é criada uma matriz transformação:
#
# \begin{bmatrix}
# 1 & 1 \\
# -1 & 0
# \end{bmatrix}

# %% [markdown]
# #  Aplicação passo a passo dessas matrizes a dois vetores arbitrários

# %% [markdown]
# ## Primeiro vetor escolhido
#
# ### Vetor arbitrário escolhido:
#
# \begin{bmatrix}
# 3 \\
# 1
# \end{bmatrix}

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,3,1,scale=1,scale_units='xy',angles='xy')
plt.xlim(0,12)
plt.ylim(0,12)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ## Vetor após a rotação

# %% [markdown]
# ### Vetor resultante da rotação:
#
# Após realizar a rotação do vetor usando a matriz resultante da rotação de 90° em sentido horário encontrada anteriormente, resultou no seguinte vetor:
#
# \begin{bmatrix}
# 1 \\
# -3
# \end{bmatrix}

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,1,-3,scale=1,scale_units='xy',angles='xy')
plt.xlim(0,10)
plt.ylim(-3,10)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ## Vetor após o cisalhamento

# %% [markdown]
# ### Vetor resultante da cisalhamento:
#
# Após realizar o cisalhamento do vetor arbitrário, utilizando a matriz resultante do cisalhamento da base, encontrei o seguinte vetor:
#
# \begin{bmatrix}
# 4 \\
# 1
# \end{bmatrix}

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,4,1,scale=1,scale_units='xy',angles='xy')
plt.xlim(0,12)
plt.ylim(0,12)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ## Vetor após a rotação e o cisalhamento
#
# Utilizando a matriz resultante para realizar a rotação e o cisalhamento do vetor encontrei o seguinte vetor:
#
# \begin{bmatrix}
# -2 \\
# -3
# \end{bmatrix}

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,-2,-3,scale=1,scale_units='xy',angles='xy')
plt.xlim(-6,6)
plt.ylim(-6,6)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# # Utilizando outro vetor arbitrário de exemplo

# %% [markdown]
# ### Vetor arbitrário que será utilizado:
#
# \begin{bmatrix}
# 2 \\
# 5
# \end{bmatrix}

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,2,5,scale=1,scale_units='xy',angles='xy')
plt.xlim(0,12)
plt.ylim(0,12)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ## Vetor resultante da rotação do vetor arbitrário:
#
# Após realizar a rotação do vetor usando a matriz resultante da rotação de 90° em sentido horário encontrada anteriormente, resultou no seguinte vetor:
#
# \begin{bmatrix}
# 5 \\
# -2
# \end{bmatrix}

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,5,-2,scale=1,scale_units='xy',angles='xy')
plt.xlim(0,6)
plt.ylim(-5,6)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ## Vetor resultante do cisalhamento do vetor arbitrário:
#
# Após realizar o cisalhamento do vetor arbitrário, utilizando a matriz resultante do cisalhamento da base, encontrei o seguinte vetor:
#
# \begin{bmatrix}
# 7 \\
# 5
# \end{bmatrix}

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,7,5,scale=1,scale_units='xy',angles='xy')
plt.xlim(0,12)
plt.ylim(0,12)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# ## Vetor resultante do cisalhamento e rotação do vetor arbitrário:
#
# Utilizando a matriz resultante para realizar a rotação e o cisalhamento do vetor encontrei o seguinte vetor:
#
# \begin{bmatrix}
# 3 \\
# -2
# \end{bmatrix}

# %%
import matplotlib.pyplot as plt

plt.quiver(0,0,3,-2,scale=1,scale_units='xy',angles='xy')
plt.xlim(-5,3)
plt.ylim(-5,3)
plt.grid(True)
plt.axhline(0,color='black',linewidth=1)
plt.axvline(0,color='black',linewidth=1)
plt.gca().set_aspect('equal', adjustable='box')
